# %% [markdown]
# ## 0. Load Data

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/final_data_multi.csv')

# %%
df.head()
# Out:
#    Unnamed: 0     Student ID  # Logins  # Content Reads  # Forum Reads  \
# 0           0  student000000       143              344             58
# 1           1  student000001        70              342              0
# 2           2  student000002        42              219              0
# 3           3  student000003        92              271              2
# 4           4  student000004       116              379              0
#
#    # Forum Posts  # Quiz Reviews before submission  \
# 0              0                                 3
# 1              0                                 4
# 2              0                                 3
# 3              0                                 6
# 4              0                                 1
#
#    Assignment 1 lateness indicator  Assignment 2 lateness indicator  \
# 0                                0                                0
# 1                                0                                0
# ...

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 486 entries, 0 to 485
# Data columns (total 23 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Student ID                                    486 non-null    object
#  1   # Logins                                      486 non-null    int64
#  2   # Content Reads                               486 non-null    int64
#  3   # Forum Reads                                 486 non-null    int64
#  4   # Forum Posts                                 486 non-null    int64
#  5   # Quiz Reviews before submission              486 non-null    int64
#  6   Assignment 1 lateness indicator               486 non-null    int64
#  7   Assignment 2 lateness indicator               486 non-null    int64
#  8   Assignment 3 lateness indicator               486 non-null    int64
# ...

# %%
df['Class'].value_counts()
# Out:
# G    465
# W     21
# Name: Class, dtype: int64

# %%
df.Class=[0 if i == "W" else 1 if i == "F" else 2 for i in df.Class]

# %%
df['Engagement Level'].value_counts()
# Out:
# H    259
# L    227
# Name: Engagement Level, dtype: int64

# %%
df['Engagement Level']=[0 if i == "L" else 1 for i in df['Engagement Level']]

# %%
df['Assignment 1 lateness indicator'].value_counts()
# Out:
# 0    474
# 1     12
# Name: Assignment 1 lateness indicator, dtype: int64

# %%
df['Assignment 2 lateness indicator'].value_counts()
# Out:
# 0    474
# 1     12
# Name: Assignment 2 lateness indicator, dtype: int64

# %%
df['Assignment 3 lateness indicator'].value_counts()
# Out:
# 0    479
# 1      7
# Name: Assignment 3 lateness indicator, dtype: int64

# %%
df_0 = df[df['Class']==0]
df_1 = df[df['Class']==1]
df_2 = df[df['Class']==2]

# %% [markdown]
# ## 1. Compare Students' engagement data based on class factor

# %%
import numpy as np

def linegraph_draw(data, label, color):
    y, binEdges = np.histogram(data, bins=20)
    bincenters = 0.5 * (binEdges[1:] + binEdges[:-1])
    plt.plot(bincenters, y, '-', c=color, label=label)

# %% [markdown]
# ### 1-1. Num of Logins

# %%
plt.rcParams["figure.figsize"] = (12,6)

plt.hist(df_0['# Logins'], bins=20)
plt.axis([min(df['# Logins']), max(df['# Logins']), 0, 225])
plt.show()

# %%
np.std(df_0['# Logins'])
# Out:
# 21.183037752772243

# %%
plt.hist(df_1['# Logins'], bins=20)
plt.axis([min(df['# Logins']), max(df['# Logins']), 0, 225])
plt.show()

# %%
np.std(df_1['# Logins'])

# %%
plt.hist(df_2['# Logins'], bins=20)
plt.axis([min(df['# Logins']), max(df['# Logins']), 0, 225])
plt.show()

# %%
np.std(df_2['# Logins'])
# Out:
# 41.223028944863614

# %%
linegraph_draw(df_0['# Logins'], "Non Pass", "g")
linegraph_draw(df_1['# Logins'], "Fair", "r")
linegraph_draw(df_2['# Logins'], "Good", "b")

plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### 1-2. Num of Content Reads

# %%
plt.hist(df_0['# Content Reads'], bins=20)
plt.axis([min(df['# Content Reads']), max(df['# Content Reads']), 0, 100])
plt.show()

# %%
np.std(df_0['# Content Reads'])
# Out:
# 93.2268829291223

# %%
plt.hist(df_1['# Content Reads'], bins=20)
plt.axis([min(df['# Content Reads']), max(df['# Content Reads']), 0, 100])
plt.show()

# %%
np.std(df_1['# Content Reads'])
# Out:
# 104.88163876520598

# %%
plt.hist(df_2['# Content Reads'], bins=20)
plt.axis([min(df['# Content Reads']), max(df['# Content Reads']), 0, 100])
plt.show()

# %%
np.std(df_2['# Content Reads'])

# %%
linegraph_draw(df_0['# Content Reads'], "Non Pass", "g")
linegraph_draw(df_1['# Content Reads'], "Fair", "r")
linegraph_draw(df_2['# Content Reads'], "Good", "b")

plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### 1-3. Num of Forum Reads

# %%
plt.hist(df_0['# Forum Reads'], bins=20)
plt.show()

# %%
np.std(df_0['# Forum Reads'])
# Out:
# 0.2935435239509036

# %%
plt.hist(df_1['# Forum Reads'], bins=20)
plt.axis([min(df['# Forum Reads']), max(df['# Forum Reads']), 0, 450])
plt.show()

# %%
np.std(df_1['# Forum Reads'])
# Out:
# 9.076385804979946

# %%
linegraph_draw(df_0['# Forum Reads'], "Non Pass", "g")
linegraph_draw(df_1['# Forum Reads'], "Pass", "r")

plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### 1-4. Num of Forum Posts

# %%
plt.hist(df_0['# Forum Posts'], bins=20)
plt.show()

# %%
np.std(df_0['# Forum Posts'])
# Out:
# 0.21295885499998005

# %%
plt.hist(df_1['# Forum Posts'], bins=20)
plt.axis([min(df['# Forum Posts']), max(df['# Forum Posts']), 0, 450])
plt.show()

# %%
np.std(df_1['# Forum Posts'])
# Out:
# 0.6177697758028278

# %%
linegraph_draw(df_0['# Forum Posts'], "Non Pass", "g")
linegraph_draw(df_1['# Forum Posts'], "Pass", "r")

plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### 1-5. Num of Quiz reviews before submission

# %%
plt.hist(df_0['# Quiz Reviews before submission'], bins=20)
plt.show()

# %%
np.std(df_0['# Quiz Reviews before submission'])
# Out:
# 1.1086139739831253

# %%
plt.hist(df_1['# Quiz Reviews before submission'], bins=20)
plt.show()

# %%
np.std(df_1['# Quiz Reviews before submission'])
# Out:
# 1.9813023555643

# %%
linegraph_draw(df_0['# Quiz Reviews before submission'], "Non Pass", "g")
linegraph_draw(df_1['# Quiz Reviews before submission'], "Pass", "r")

plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### 1-5. Average time to submit assignment (in hours)

# %%
plt.hist(df_0['Average time to submit assignment (in hours)'], bins=20)
plt.show()

# %%
np.std(df_0['Average time to submit assignment (in hours)'])
# Out:
# 129.5941649101837

# %%
plt.hist(df_1['Average time to submit assignment (in hours)'], bins=20)
plt.show()

# %%
np.std(df_1['Average time to submit assignment (in hours)'])
# Out:
# 82.01419520514335

# %%
linegraph_draw(df_0['Average time to submit assignment (in hours)'], "Non Pass", "g")
linegraph_draw(df_1['Average time to submit assignment (in hours)'], "Pass", "r")

plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### 1-6. Engagement level

# %%
plt.hist(df_0['Engagement Level'], bins=20)
plt.show()

# %%
plt.hist(df_1['Engagement Level'], bins=20)
plt.show()

# %% [markdown]
# ## 2. Compare Students' performance data based on class factor

# %% [markdown]
# ### 2-1. Quiz01

# %%
plt.hist(df_0['Quiz01 [10]'], bins=20)
plt.show()

# %%
np.std(df_0['Quiz01 [10]'])
# Out:
# 31.70334431596021

# %%
plt.hist(df_1['Quiz01 [10]'], bins=20)
plt.show()

# %%
np.std(df_1['Quiz01 [10]'])
# Out:
# 11.043413840262975

# %%
linegraph_draw(df_0['Quiz01 [10]'], "Non Pass", "g")
linegraph_draw(df_1['Quiz01 [10]'], "Pass", "r")

plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### 2-2. Assignment01

# %%
plt.hist(df_0['Assignment01 [8]'], bins=20)
plt.show()

# %%
np.std(df_0['Assignment01 [8]'])
# Out:
# 28.00323920362949

# %%
plt.hist(df_1['Assignment01 [8]'], bins=20)
plt.show()

# %%
np.std(df_1['Assignment01 [8]'])
# Out:
# 14.683634746857438

# %%
linegraph_draw(df_0['Assignment01 [8]'], "Non Pass", "g")
linegraph_draw(df_1['Assignment01 [8]'], "Pass", "r")

plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### 2-3. Assginment02

# %%
plt.hist(df_0['Assignment02 [12]'], bins=20)
plt.show()

# %%
np.std(df_0['Assignment02 [12]'])
# Out:
# 27.92336451279261

# %%
plt.hist(df_1['Assignment02 [12]'], bins=20)
plt.show()

# %%
np.std(df_1['Assignment02 [12]'])
# Out:
# 11.01478756716298

# %%
linegraph_draw(df_0['Assignment02 [12]'], "Non Pass", "g")
linegraph_draw(df_1['Assignment02 [12]'], "Pass", "r")

plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### 2-4. Assignment03

# %%
plt.hist(df_0['Assignment03 [25]'], bins=20)
plt.show()

# %%
np.std(df_0['Assignment03 [25]'])
# Out:
# 28.505479443023653

# %%
plt.hist(df_1['Assignment03 [25]'], bins=20)
plt.show()

# %%
np.std(df_1['Assignment03 [25]'])
# Out:
# 8.903793551063153

# %%
linegraph_draw(df_0['Assignment03 [25]'], "Non Pass", "g")
linegraph_draw(df_1['Assignment03 [25]'], "Pass", "r")

plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### 2-5. Midterm

# %%
plt.hist(df_0['Midterm Exam [20]'], bins=20)
plt.show()

# %%
np.std(df_0['Midterm Exam [20]'])
# Out:
# 18.5854647812151

# %%
plt.hist(df_1['Midterm Exam [20]'], bins=20)
plt.show()

# %%
np.std(df_1['Midterm Exam [20]'])
# Out:
# 10.968474780492052

# %%
linegraph_draw(df_0['Midterm Exam [20]'], "Non Pass", "g")
linegraph_draw(df_1['Midterm Exam [20]'], "Pass", "r")

plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### 2-6. Final exam

# %%
plt.hist(df_0['Final Exam [35]'], bins=20)
plt.show()

# %%
np.std(df_0['Final Exam [35]'])
# Out:
# 19.28624337898569

# %%
plt.hist(df_1['Final Exam [35]'], bins=20)
plt.show()

# %%
np.std(df_1['Final Exam [35]'])
# Out:
# 13.212904625895987

# %%
linegraph_draw(df_0['Final Exam [35]'], "Non Pass", "g")
linegraph_draw(df_1['Final Exam [35]'], "Pass", "r")

plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Heatmap with features

# %%
plt.rcParams["figure.figsize"] = (16,12)
corr = df.corr()

sns.heatmap(corr, cmap="Blues", annot=True, xticklabels=corr.columns, yticklabels=corr.columns)

# %%
corr["Class"]
# Out:
# # Logins                                        0.181986
# # Content Reads                                 0.176565
# # Forum Reads                                   0.049276
# # Forum Posts                                   0.034517
# # Quiz Reviews before submission                0.102897
# Assignment 1 lateness indicator                -0.422663
# Assignment 2 lateness indicator                -0.487874
# Assignment 3 lateness indicator                -0.398982
# Assignment 1 duration to submit (in hours)     -0.288950
# Assignment 2 duration to submit (in hours)     -0.210851
# Assignment 3 duration to submit (in hours)     -0.298755
# Average time to submit assignment (in hours)   -0.285616
# Engagement Level                                0.105298
# Quiz01 [10]                                     0.378246
# Assignment01 [8]                                0.484448
# Midterm Exam [20]                               0.305311
# ...
